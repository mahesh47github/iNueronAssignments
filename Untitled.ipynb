# %%
import pandas as pd

# %%
train_set = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data', header = None)

# %%
col_labels = ['age', 'workclass', 'fnlwgt', 'education', 'education_num',
'marital_status', 'occupation','relationship', 'race', 'sex', 'capital_gain',
'capital_loss', 'hours_per_week', 'native_country', 'wage_class']
train_set.columns = col_labels
train_set.head(50)
# Out:
#     age          workclass  fnlwgt      education  education_num  \
# 0    39          State-gov   77516      Bachelors             13
# 1    50   Self-emp-not-inc   83311      Bachelors             13
# 2    38            Private  215646        HS-grad              9
# 3    53            Private  234721           11th              7
# 4    28            Private  338409      Bachelors             13
# 5    37            Private  284582        Masters             14
# 6    49            Private  160187            9th              5
# 7    52   Self-emp-not-inc  209642        HS-grad              9
# 8    31            Private   45781        Masters             14
# 9    42            Private  159449      Bachelors             13
# 10   37            Private  280464   Some-college             10
# 11   30          State-gov  141297      Bachelors             13
# 12   23            Private  122272      Bachelors             13
# ...

# %%
train_set.describe()
# Out:
#                 age        fnlwgt  education_num  capital_gain  capital_loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours_per_week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
train_set = train_set.filter(items= train_set=='  ?', axis=1)

train_set.head(50)
# Out:
#     age          workclass  fnlwgt      education  education_num  \
# 0    39          State-gov   77516      Bachelors             13
# 1    50   Self-emp-not-inc   83311      Bachelors             13
# 2    38            Private  215646        HS-grad              9
# 3    53            Private  234721           11th              7
# 4    28            Private  338409      Bachelors             13
# 5    37            Private  284582        Masters             14
# 6    49            Private  160187            9th              5
# 7    52   Self-emp-not-inc  209642        HS-grad              9
# 8    31            Private   45781        Masters             14
# 9    42            Private  159449      Bachelors             13
# 10   37            Private  280464   Some-college             10
# 11   30          State-gov  141297      Bachelors             13
# 12   23            Private  122272      Bachelors             13
# ...

# %%
#df1[df1['col'].str.contains(r'foo(?!$)')]
#train_set[train_set['fnlwgt'].astype(str).str.contains('?')]
#train_set.head()                             
train_set['fnlwgt'].astype(str).str.contains('?')
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-145-98a81f771034> in <module>
#       2 #train_set[train_set['fnlwgt'].astype(str).str.contains('?')]
#       3 #train_set.head()
# ----> 4 train_set['fnlwgt'].astype(str).str.contains('?')
#
# ~\Anaconda3\lib\site-packages\pandas\core\strings.py in contains(self, pat, case, flags, na, regex)
#    2521     def contains(self, pat, case=True, flags=0, na=np.nan, regex=True):
#    2522         result = str_contains(self._parent, pat, case=case, flags=flags, na=na,
# -> 2523                               regex=regex)
#    2524         return self._wrap_result(result, fill_value=na)
#    2525
#
# ~\Anaconda3\lib\site-packages\pandas\core\strings.py in str_contains(arr, pat, case, flags, na, regex)
#     297             flags |= re.IGNORECASE
#     298
# --> 299         regex = re.compile(pat, flags=flags)
#     300
# ...

# %%
#train_set['wage_class']=train_set['wage_class'].map(lambda x: str(x)).map(lambda x: 0 if x=="<=50K" else  1)
#train_set.head()
#train_set['wage_class'] = train_set['wage_class'].astype(str)
#train_set.dtypes
#train_set.wage_class.apply("string")
#train_set['wage_class'].head(20)

#train_set['wage_class']=train_set['wage_class'].map(lambda x: str(x))
#train_set['wage_class'].astype(str)

# %%
train_set.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education_num      int64
# marital_status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital_gain       int64
# capital_loss       int64
# hours_per_week     int64
# native_country    object
# wage_class        object
# dtype: object

# %%
train_set['sex'] = train_set['sex'].map({'Male': 0, 'Female': 1})

# %%
train_set['sex'].replace(['Female','Male'], [0,1], inplace=True)

# %%
train_set.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race  sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White  NaN
# 1   Married-civ-spouse     Exec-managerial         Husband   White  NaN
# 2             Divorced   Handlers-cleaners   Not-in-family   White  NaN
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black  NaN
# 4   Married-civ-spouse      Prof-specialty            Wife   Black  NaN
#
#    capital_gain  capital_loss  hours_per_week  native_country wage_class
# 0          2174             0              40   United-States      <=50K
# ...

# %%
train_set['wage_class'] = train_set['wage_class'].apply({'>50k':1, '<=50k':0}.get)

# %%
train_set.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country wage_class
# ...

# %%
type(train_set)
# Out:
# pandas.core.frame.DataFrame

# %%
#train_set['wage_class'].replace(['<=50k','>50k'], [0,1], inplace=True)
#train_set['wage_class'] = train_set['wage_class'].apply(lambda x: 0 if ' <=50K'  else 1)

# %%
#train_set.head()

# %%
#train_set['wage_class']=train_set['wage_class'].map(lambda x: str(x)).map(lambda x: 0 if x=="<=50K" else  1)

# %%
#train_set['wage_class'] = train_set['wage_class'].apply(lambda x: x.strip()).map(lambda x: 0 if x=="<=50K" else  1)
train_set['wage_class'] = train_set['wage_class'].apply(lambda x: 0 if x==' <=50K'  else 1)

# %%
train_set.head(20)
# Out:
#     age          workclass  fnlwgt      education  education_num  \
# 0    39          State-gov   77516      Bachelors             13
# 1    50   Self-emp-not-inc   83311      Bachelors             13
# 2    38            Private  215646        HS-grad              9
# 3    53            Private  234721           11th              7
# 4    28            Private  338409      Bachelors             13
# 5    37            Private  284582        Masters             14
# 6    49            Private  160187            9th              5
# 7    52   Self-emp-not-inc  209642        HS-grad              9
# 8    31            Private   45781        Masters             14
# 9    42            Private  159449      Bachelors             13
# 10   37            Private  280464   Some-college             10
# 11   30          State-gov  141297      Bachelors             13
# 12   23            Private  122272      Bachelors             13
# ...
